# %% [markdown]
# Feature Selection using Backward Elimination

# %%
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
import statsmodels.api as sm 
from openFile import OpenCleanFile

# %%
clean = OpenCleanFile()
#for name in ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY']:
    #clean.df_housing[name] = clean.df_housing[name].str.strip()
alpha_columns = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', "TAX CLASS AT PRESENT",
"BUILDING CLASS AT TIME OF SALE", "BOROUGH_NAME"]
#X = clean.df_housing.drop(alpha_columns, axis=1)
X = clean.df_housing.drop(["SALE PRICE", "SALE DATE"], axis=1)
X = pd.get_dummies(X, drop_first=True)
y = clean.df_housing["SALE PRICE"]
X.head()
# Out:
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  5                 0            5              1633
# 1                 10                 0           10              2272
# 2                  6                 0            6              2369
# 3                  8                 0            8              1750
# 4                 24                 0           24              4489
#
#    GROSS SQUARE FEET  YEAR BUILT  SALE_MONTH  AGE  NEIGHBORHOOD_ALPHABET CITY  \
# 0               6440        1900           7  122                           1
# 1               6794        1913           9  109                           1
# 2               4615        1900          11  122                           1
# 3               4226        1920           9  102                           1
# 4              18523        1920          11  102                           1
#
#    NEIGHBORHOOD_ANNADALE  ...  BUILDING CLASS AT TIME OF SALE_W2  \
# ...

# %%
#lreg = LinearRegression()
#sfs1 = sfs(lreg, k_features=4, forward=False, verbose=1, scoring='neg_mean_squared_error')
#sfs1 = sfs1.fit(X, y)
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             SALE PRICE   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     6.684
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        19:00:59   Log-Likelihood:            -1.4121e+05
# No. Observations:                8482   AIC:                         2.916e+05
# Df Residuals:                    3875   BIC:                         3.241e+05
# Df Model:                        4606
# Covariance Type:            nonrobust
# ...
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
feat_names = list(sfs.k_feature_names_)
print(feat_names)
# Out:
# ['BLOCK', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'TAX CLASS AT TIME OF SALE']

# %%
df_new_housing = clean.df_housing[feat_names]
df_new_housing['SALE PRICE'] = clean.df_housing['SALE PRICE']
df_new_housing.head()
# Out:
# C:\Users\hijik\AppData\Local\Temp\ipykernel_10696\3696841722.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_housing['SALE PRICE'] = clean.df_housing['SALE PRICE']
#   BLOCK  LAND SQUARE FEET  GROSS SQUARE FEET TAX CLASS AT TIME OF SALE  \
# 0   392              1633               6440                         2
# 1   402              2272               6794                         2
# 2   404              2369               4615                         2
# 3   406              1750               4226                         2
# 4   387              4489              18523                         2
#
#    SALE PRICE
# 0     6625000
# 1     3936272
# 2     8000000
# 3     3192840
# 4    16232000

# %%
# shape of new and original data
df_new_housing.shape, clean.df_housing.shape
# Out:
# ((8482, 17), (8482, 17))
